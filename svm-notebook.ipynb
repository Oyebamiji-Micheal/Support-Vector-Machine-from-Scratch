# %% [markdown]
# <h1 align="center" style="background-color:#0b0504;color:white;border-radius: 8px; padding:12px">Bank Customer Churn Prediction using SVM</h1>

# %% [markdown]
# <h2 style="background-color:#0b0504;color:white;border-radius: 8px; padding:12px">1. Import Libraries and Load Dataset</h2>

# %%
import numpy as np
import pandas as pd
pd.set_option("display.max_columns", 120)
pd.set_option("display.max_rows", 120)
pd.set_option('display.float_format', '{:.2f}'.format)

import warnings 
warnings.simplefilter(action='ignore', category=FutureWarning)
# warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('/kaggle/input/bank-customer-churn-prediction/Churn_Modelling.csv')

# %% [markdown]
# <h2 style="background-color:#0b0504;color:white;border-radius: 8px; padding:12px">2. Dataset Preview</h2>

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave          619    France  Female 42.00
# 1          2    15647311      Hill          608     Spain  Female 41.00
# 2          3    15619304      Onio          502    France  Female 42.00
# 3          4    15701354      Boni          699    France  Female 39.00
# 4          5    15737888  Mitchell          850     Spain  Female 43.00
#
#    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2      0.00              1       1.00            1.00
# 1       1  83807.86              1       0.00            1.00
# 2       8 159660.80              3       1.00            0.00
# 3       1      0.00              2       0.00            0.00
# 4       2 125510.82              1        NaN            1.00
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10002 entries, 0 to 10001
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10002 non-null  int64
#  1   CustomerId       10002 non-null  int64
#  2   Surname          10002 non-null  object
#  3   CreditScore      10002 non-null  int64
#  4   Geography        10001 non-null  object
#  5   Gender           10002 non-null  object
#  6   Age              10001 non-null  float64
#  7   Tenure           10002 non-null  int64
#  8   Balance          10002 non-null  float64
#  9   NumOfProducts    10002 non-null  int64
#  10  HasCrCard        10001 non-null  float64
#  11  IsActiveMember   10001 non-null  float64
#  12  EstimatedSalary  10002 non-null  float64
#  13  Exited           10002 non-null  int64
# dtypes: float64(5), int64(6), object(3)
# memory usage: 1.1+ MB

# %%
data['Exited'].unique()
# Out:
# array([1, 0])

# %%
data.describe()
# Out:
#        RowNumber  CustomerId  CreditScore      Age   Tenure   Balance  \
# count   10002.00    10002.00     10002.00 10001.00 10002.00  10002.00
# mean     5001.50 15690933.45       650.56    38.92     5.01  76491.11
# std      2887.47    71931.77        96.66    10.49     2.89  62393.47
# min         1.00 15565701.00       350.00    18.00     0.00      0.00
# 25%      2501.25 15628524.75       584.00    32.00     3.00      0.00
# 50%      5001.50 15690732.00       652.00    37.00     5.00  97198.54
# 75%      7501.75 15753225.50       718.00    44.00     7.00 127647.84
# max     10000.00 15815690.00       850.00    92.00    10.00 250898.09
#
#        NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary   Exited
# count       10002.00   10001.00        10001.00         10002.00 10002.00
# mean            1.53       0.71            0.51        100083.33     0.20
# std             0.58       0.46            0.50         57508.12     0.40
# min             1.00       0.00            0.00            11.58     0.00
# 25%             1.00       0.00            0.00         50983.75     0.00
# 50%             1.00       1.00            1.00        100185.24     0.00
# 75%             2.00       1.00            1.00        149383.65     0.00
# max             4.00       1.00            1.00        199992.48     1.00

# %% [markdown]
# <h2 style="background-color:#0b0504;color:white;border-radius: 8px; padding:12px">3. Data Wrangling</h2>

# %% [markdown]
# <h4 style="background-color:#0b0504;color:white;border-radius: 8px; padding:12px">3.1. Drop ID columns</h4>

# %%
data = data.drop(columns=['RowNumber', 'CustomerId'], axis=1)

# %% [markdown]
# <h4 style="background-color:#0b0504;color:white;border-radius: 8px; padding:12px">3.2. Drop NaNs</h4>

# %%
data = data.dropna()

# %% [markdown]
# <h4 style="background-color:#0b0504;color:white;border-radius: 8px; padding:12px">3.3. Change Column DataType</h4>

# %%
columns_to_convert = ['HasCrCard', 'IsActiveMember', 'Tenure']

for column in columns_to_convert:
    data[column] = data[column].astype('int').astype('object')

# %% [markdown]
# <h2 style="background-color:#0b0504;color:white;border-radius: 8px; padding:12px">4. Exploratory Data Analysis</h2>

# %%
# from fasteda import fast_eda
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
sns.set_style("darkgrid")

# %%
def custom_show(fig):
    fig.update_layout(title_x=0.5, title_y=0.9)
#     fig.show('png', width=1000, height=550)

# %%
plot_color = ['#FF6F61', '#008080']
sns.set_palette(['#008080', 'black'])

# %%
# !pip install -U kaleido

# %%
def custom_barplot(dataframe: pd.DataFrame, column: str, titles: list, labels: dict) -> go.Figure:
    """create a barplot for visualizing a column distribution and 
       its relationship between the target column 
       
       df: the data from which we intend to create the plot -> pandas DataFrame
       
       column: the x-axis column name -> str
       
       titles: A list of the plot and x-axis title respectively -> list
       
       label: a mapping of the x-label and y-label -> dict
    """
    df = pd.crosstab(dataframe[column], dataframe['Exited'])
    data_normalized = df.div(df.sum(1).astype('float'), axis=0).sort_values(by=0)

    fig = px.bar(data_normalized,
                 x=data_normalized.index,
                 y=[0, 1],
                 color_discrete_sequence=plot_color,
                 title=titles[0],
                 labels=labels,
                 width=800,
                 height=500)

    fig.update_layout(xaxis_title=titles[1],
                      yaxis_title='',
                      legend_title='Customer Churn?',
                      title_x=0.5)

    return fig

# %% [markdown]
# <h4 style="background-color:#0b0504;color:white;border-radius: 8px; padding:12px">4.1. Univariate Analysis</h4>

# %% [markdown]
# **Exited**

# %%
exited_count = data['Exited'].value_counts()
exited_count
# Out:
# Exited
# 0    7960
# 1    2038
# Name: count, dtype: int64

# %%
fig = px.pie(
    exited_count, values=exited_count.values, names=['No', 'Yes'],
    title='Proportion of customer churn',
    color_discrete_sequence=plot_color,
)

fig.update_layout(legend_title_text='Customer churn?', title_x=0.3, title_y=0.95,)
custom_show(fig)

# %% [markdown]
# <h4 style="background-color:#0b0504;color:white;border-radius: 8px; padding:12px">4.2. Bivariate Analysis</h4>

# %% [markdown]
# **Age**

# %%
fig = px.histogram(data, x='Age', color='Exited', title='Age distribution', color_discrete_sequence=plot_color)
fig.update_layout(title_x=0.5, title_y=0.9, legend_title='Customer Churn')
custom_show(fig)

# %% [markdown]
# **Gender**

# %%
data['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
fig = px.histogram(data, x='Gender', color='Exited', 
                   color_discrete_sequence=plot_color,
                   title="Gender Churn", width=700, height=500)
fig.update_layout(title_x=0.5, legend_title='Customer Churn')
custom_show(fig)

# %% [markdown]
# **Tenure**

# %%
data['Tenure'].unique()
# Out:
# array([2, 1, 8, 4, 6, 3, 10, 5, 7, 9, 0], dtype=object)

# %%
titles = ['Proportion of customer churn by tenure', 'Tenure']
labels={'index': 'Tenure', 'value': 'Proportion'}

custom_barplot(data, 'Tenure', titles, labels)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="1bd873c4-8b5a-4f3f-848c-e7f6d491b2b2" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1bd873c4-8b5a-4f3f-848c-e7f6d491b2b2")) {                    Plotly.newPlot(                        "1bd873c4-8b5a-4f3f-848c-e7f6d491b2b2",                        [{"alignmentgroup":"True","hovertemplate":"variable=0\u003cbr\u003eTenure=%{x}\u003cbr\u003eProportion=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#FF6F61","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"textposition":"auto","x":[0,1,9,3,5,10,4,6,8,2,7],"xaxis":"x","y":[0.7699757869249395,0.7758454106280194,0.7835365853658537,0.7881188118811882,0.7934782608695652,0.7938775510204081,0.7947421638018201,0.7973112719751809,0.8078048780487805,0.8078393881453155,0.8276533592989289],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=1\u003cbr\u003eTenure=%{x}\u003cbr\u003eProportion=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1","marker":{"color":"#008080","pattern":{"shape":""}},"name":"1","offsetgroup":"1","orientation":"v","showlegend":true,"textposition":"auto","x":[0,1,9,3,5,10,4,6,8,2,7],"xaxis":"x","y":[0.23002421307506055,0.22415458937198068,0.21646341463414634,0.21188118811881188,0.20652173913043478,0.20612244897959184,0.20525783619817997,0.20268872802481902,0.19219512195121952,0.1921606118546845,0.17234664070107109],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444444 ...

# %% [markdown]
# There appears to be no correlation between `tenure` and `customer churn`. This column is best one-hot-encoded rather than ordinal encoded.

# %% [markdown]
# **NumOfProducts**

# %%
titles = ['Proportion of customer churn by number of products', 'NumOfProducts']
labels={'index': 'Number of Products', 'value': 'Proportion'}

custom_barplot(data, 'NumOfProducts', titles, labels)
# Out:
# <div>                            <div id="dbac9acd-e790-42f4-9adf-12c619b1b7c7" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dbac9acd-e790-42f4-9adf-12c619b1b7c7")) {                    Plotly.newPlot(                        "dbac9acd-e790-42f4-9adf-12c619b1b7c7",                        [{"alignmentgroup":"True","hovertemplate":"variable=0\u003cbr\u003eNumOfProducts=%{x}\u003cbr\u003eProportion=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#FF6F61","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"textposition":"auto","x":[4,3,1,2],"xaxis":"x","y":[0.0,0.17293233082706766,0.7228014951800118,0.9239485726737852],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=1\u003cbr\u003eNumOfProducts=%{x}\u003cbr\u003eProportion=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1","marker":{"color":"#008080","pattern":{"shape":""}},"name":"1","offsetgroup":"1","orientation":"v","showlegend":true,"textposition":"auto","x":[4,3,1,2],"xaxis":"x","y":[1.0,0.8270676691729323,0.2771985048199882,0.07605142732621487],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter" ...

# %% [markdown]
# There appears to be no correlation between `tenure` and `number of products`. Also, this column is best one-hot-encoded rather than ordinal encoded.

# %% [markdown]
# <h2 style="background-color:#0b0504;color:white;border-radius: 8px; padding:12px">5. Data Preparation and Preprocessing</h2>

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split

from sklearn import set_config
set_config(display='diagram')

# %% [markdown]
# <h4 style="background-color:#0b0504;color:white;border-radius: 8px; padding:12px">5.1. Ordinal Encode Gender Column</h4>

# %%
mapping = {'Male': 0, 'Female': 1}

# %%
data['Gender'] = data['Gender'].map(mapping)

# %% [markdown]
# <h4 style="background-color:#0b0504;color:white;border-radius: 8px; padding:12px">5.2. Data Preprocessing Pipeline</h4>

# %%
X = data.drop(columns=['Exited'], axis=1)
y = data['Exited']

# %%
num_cols = X.select_dtypes(include=np.number).columns.to_list()
cat_cols = X.select_dtypes(exclude=np.number).columns.to_list()

print(num_cols, end='\n\n')
print(cat_cols)
# Out:
# ['CreditScore', 'Gender', 'Age', 'Balance', 'NumOfProducts', 'EstimatedSalary']
#
# ['Surname', 'Geography', 'Tenure', 'HasCrCard', 'IsActiveMember']

# %%
num_pipeline = Pipeline(steps=[
    ('scaler', MinMaxScaler())
])

cat_pipeline = Pipeline(steps=[
    ('one_hot_enc', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

# %%
col_trans = ColumnTransformer(transformers=[
    ('num_pipeline', num_pipeline, num_cols),
    ('cat_pipeline', cat_pipeline, cat_cols),
    ],
    remainder='drop',
    n_jobs=-1
)

# %%
set_config(display='diagram')
display(col_trans)
# Out:
# ColumnTransformer(n_jobs=-1,
#                   transformers=[('num_pipeline',
#                                  Pipeline(steps=[('scaler', MinMaxScaler())]),
#                                  ['CreditScore', 'Gender', 'Age', 'Balance',
#                                   'NumOfProducts', 'EstimatedSalary']),
#                                 ('cat_pipeline',
#                                  Pipeline(steps=[('one_hot_enc',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  ['Surname', 'Geography', 'Tenure', 'HasCrCard',
#                                   'IsActiveMember'])])

# %%
col_trans.fit(X)
# Out:
# ColumnTransformer(n_jobs=-1,
#                   transformers=[('num_pipeline',
#                                  Pipeline(steps=[('scaler', MinMaxScaler())]),
#                                  ['CreditScore', 'Gender', 'Age', 'Balance',
#                                   'NumOfProducts', 'EstimatedSalary']),
#                                 ('cat_pipeline',
#                                  Pipeline(steps=[('one_hot_enc',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  ['Surname', 'Geography', 'Tenure', 'HasCrCard',
#                                   'IsActiveMember'])])

# %%
X_preprocessed = col_trans.transform(X)

# %%
X_preprocessed.shape, y.shape
# Out:
# ((9998, 2956), (9998,))

# %% [markdown]
# <h4 style="background-color:#0b0504;color:white;border-radius: 8px; padding:12px">5.3. Partition Dataset into Training and Test Set</h4>

# %%
y = np.where(y == 0, -1, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y, test_size=0.2, random_state=42)

# %% [markdown]
# <h2 style="background-color:#0b0504;color:white;border-radius: 8px; padding:12px">6. Support Vector Machine Classifier</h2>

# %%
class SVM:
    def __init__(self, learning_rate=0.001, lambda_param=0.01, n_iters=1000):
        self.learning_rate = learning_rate
        self.lambda_param = lambda_param
        self.n_iters = n_iters
        self.w = None
        self.b = None

    def fit(self, X, y):
        n_samples, n_features = X.shape
        y_ = np.where(y <= 0, -1, 1)  # Ensure the labels are -1 and 1

        self.w = np.zeros(n_features)
        self.b = 0

        for _ in range(self.n_iters):
            for idx, x_i in enumerate(X):
                condition = y_[idx] * (np.dot(x_i, self.w) - self.b) >= 1
                if condition:
                    self.w -= self.learning_rate * (2 * self.lambda_param * self.w)
                else:
                    self.w -= self.learning_rate * (2 * self.lambda_param * self.w - np.dot(x_i, y_[idx]))
                    self.b -= self.learning_rate * y_[idx]

    def predict(self, X):
        linear_output = np.dot(X, self.w) - self.b
        return np.sign(linear_output)

def accuracy(y_true, y_pred):
#     return accuracy_score(y_true, y_pred)
    return np.mean(y_true == y_pred)

# %%
svm = SVM()
svm.fit(X_train, y_train)

# %%
predictions = svm.predict(X_test)

# %%
acc = accuracy(y_test, predictions)
print(f'Accuracy: {acc}')
# Out:
# Accuracy: 0.786
